# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
a = 'list'

# %%
a
# Out:
# 'list'

# %%
type(a)
# Out:
# int

# %%
a = []

# %%
type(a)
# Out:
# list

# %%
a.append(1)

# %%
a.extend([1,2,3,4])

# %%
a
# Out:
# [1, 1, 2, 3, 4]

# %%
a.extend(["list", 0.5, [1,2,1]])

# %%
a
# Out:
# [1, 1, 2, 3, 4, 'list', 0.5, [1, 2, 1]]

# %%
a[0]
# Out:
# 1

# %%
len(a)
# Out:
# 8

# %%
type(a[4])
# Out:
# int

# %%
a[5][0]
# Out:
# 'l'

# %%
a[5][1]
# Out:
# 'i'

# %%
a[7][2]
# Out:
# 1

# %%
a[1] = 'SNTP'

# %%
a[1]
# Out:
# 'SNTP'

# %%
a
# Out:
# [1, 'SNTP', 2, 3, 4, 'list', 0.5, [1, 2, 1]]

# %%
a.pop()
a
# Out:
# [1, 'SNTP', 2, 3, 4, 'list', 0.5]

# %%
a.remove(0.5)
a
# Out:
# [1, 'SNTP', 2, 3, 4, 'list']

# %%
a.pop(len(a)-1)
# Out:
# 'list'

# %%
a
# Out:
# [1, 'SNTP', 2, 3, 4]

# %%
a.insert(1, 'index')
a
# Out:
# [1, 'index', 'SNTP', 2, 3, 4]

# %%
a.extend([1,2,3])
a
# Out:
# [1, 'index', 'SNTP', 2, 3, 4, 1, 2, 3]

# %%
b = () #tuple

# %%
b = (0.5, 15, 'list')
b
# Out:
# (0.5, 15, 'list')

# %%
type(b)
# Out:
# tuple

# %%
len(b)
# Out:
# 3

# %%
b[0] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 b[0] = 1
#
# TypeError: 'tuple' object does not support item assignment

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
print(nx.__version__) #checking version
# Out:
# 3.1

# %%
import matplotlib as plt1
print(plt1.__version__)
# Out:
# 3.8.0

# %%
n = 10 #10 nodes
G = nx.empty_graph(n) #empty graph

# %%
G

# %%
nx.draw(G)

# %%
nx.draw(G, with_labels=True)

# %%
K_10 = nx.complete_graph(n)

# %%
nx.draw(K_10, with_labels=True)

# %%
K_10_D = nx.DiGraph(K_10)

# %%
nx.draw(K_10_D, with_labels=True)

# %%
st = nx.star_graph(n)
nx.draw(st, with_labels=True)

# %%
rt = nx.random_tree(n*2)
nx.draw(rt, with_labels=True)

# %%
rt = nx.random_tree(n)
nx.draw(rt, with_labels=True)

# %%
bt = nx.balanced_tree(3,2)
nx.draw(bt, with_labels=True)

# %%
bt = nx.balanced_tree(4,3)
nx.draw(bt, with_labels=True)

# %%
import pandas as pd

# %%
df = pd.read_csv('us_edgelist.csv')

# %%
df.head()

# %%
type(df)
